# %% [markdown]
# # Overview
# We try here to improve another public U-Net model: https://www.kaggle.com/kmader/baseline-u-net-model-part-1 which shows how to extract the segmentation map for the ships, augment the images and train a simple DNN model to detect them. A few additional tweaks like balancing the ship-count out a little better have also been done.
#
# We are using a different loss function (closer to the competition scoring) and also fix and improve some visualisation functions and the submission itself.

# %% [markdown]
# ## Model Parameters
# We might want to adjust these later (or do some hyperparameter optimizations)

# %%
BATCH_SIZE = 40
EDGE_CROP = 16
GAUSSIAN_NOISE = 0.1
UPSAMPLE_MODE = 'SIMPLE'
# downsampling inside the network
NET_SCALING = (1, 1)
# downsampling in preprocessing
IMG_SCALING = (3, 3)
# number of validation images to use
VALID_IMG_COUNT = 900
# maximum number of steps_per_epoch in training
MAX_TRAIN_STEPS = 9
MAX_TRAIN_EPOCHS = 99
AUGMENT_BRIGHTNESS = False

# %%
# imports 
import os
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from skimage.io import imread
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from skimage.segmentation import mark_boundaries
from skimage.util import montage2d as montage
from skimage.morphology import binary_opening, disk, label
import gc; gc.enable() # memory is tight

montage_rgb = lambda x: np.stack([montage(x[:, :, :, i]) for i in range(x.shape[3])], -1)
ship_dir = '../input'
train_image_dir = os.path.join(ship_dir, 'train')
test_image_dir = os.path.join(ship_dir, 'test')

# %%
def multi_rle_encode(img, **kwargs):
    '''
    Encode connected regions as separated masks
    '''
    labels = label(img)
    if img.ndim > 2:
        return [rle_encode(np.sum(labels==k, axis=2), **kwargs) for k in np.unique(labels[labels>0])]
    else:
        return [rle_encode(labels==k, **kwargs) for k in np.unique(labels[labels>0])]

# ref: https://www.kaggle.com/paulorzp/run-length-encode-and-decode
def rle_encode(img, min_max_threshold=1e-3, max_mean_threshold=None):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    if np.max(img) < min_max_threshold:
        return '' ## no need to encode if it's all zeros
    if max_mean_threshold and np.mean(img) > max_mean_threshold:
        return '' ## ignore overfilled mask
    pixels = img.T.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

def rle_decode(mask_rle, shape=(768, 768)):
    '''
    mask_rle: run-length as string formated (start length)
    shape: (height,width) of array to return 
    Returns numpy array, 1 - mask, 0 - background
    '''
    s = mask_rle.split()
    starts, lengths = [np.asarray(x, dtype=int) for x in (s[0:][::2], s[1:][::2])]
    starts -= 1
    ends = starts + lengths
    img = np.zeros(shape[0]*shape[1], dtype=np.uint8)
    for lo, hi in zip(starts, ends):
        img[lo:hi] = 1
    return img.reshape(shape).T  # Needed to align to RLE direction

def masks_as_image(in_mask_list):
    # Take the individual ship masks and create a single mask array for all ships
    all_masks = np.zeros((768, 768), dtype = np.uint8)
    for mask in in_mask_list:
        if isinstance(mask, str):
            all_masks |= rle_decode(mask)
    return all_masks

def masks_as_color(in_mask_list):
    # Take the individual ship masks and create a color mask array for each ships
    all_masks = np.zeros((768, 768), dtype = np.float)
    scale = lambda x: (len(in_mask_list)+x+1) / (len(in_mask_list)*2) ## scale the heatmap image to shift 
    for i,mask in enumerate(in_mask_list):
        if isinstance(mask, str):
            all_masks[:,:] += scale(i) * rle_decode(mask)
    return all_masks

# %%
masks = pd.read_csv(os.path.join('../input/', 'train_ship_segmentations.csv'))
not_empty = pd.notna(masks.EncodedPixels)
print(not_empty.sum(), 'masks in', masks[not_empty].ImageId.nunique(), 'images')
print((~not_empty).sum(), 'empty images in', masks.ImageId.nunique(), 'total images')
masks.head()
# Out:
# 56030 masks in 29070 images
# 75000 empty images in 104070 total images
#          ImageId                                      EncodedPixels
# 0  00003e153.jpg                                                NaN
# 1  000155de5.jpg  264661 17 265429 33 266197 33 266965 33 267733...
# 2  00021ddc3.jpg  101361 1 102128 3 102896 4 103663 6 104430 9 1...
# 3  00021ddc3.jpg  95225 2 95992 5 96760 7 97527 9 98294 9 99062 ...
# 4  00021ddc3.jpg  74444 4 75212 4 75980 4 76748 4 77517 3 78285 ...

# %% [markdown]
# # Make sure encode/decode works
# Given the process
# $$  RLE_0 \stackrel{Decode}{\longrightarrow} \textrm{Image}_0 \stackrel{Encode}{\longrightarrow} RLE_1 \stackrel{Decode}{\longrightarrow} \textrm{Image}_1 $$
# We want to check if/that
# $ \textrm{Image}_0 \stackrel{?}{=} \textrm{Image}_1 $
# We could check the RLEs as well but that is more tedious. Also depending on how the objects have been labeled we might have different counts.

# %%
fig, (ax1, ax2, ax3, ax4) = plt.subplots(1, 4, figsize = (16, 5))
rle_0 = masks.query('ImageId=="00021ddc3.jpg"')['EncodedPixels']
img_0 = masks_as_image(rle_0)
ax1.imshow(img_0)
ax1.set_title('Mask as image')
rle_1 = multi_rle_encode(img_0)
img_1 = masks_as_image(rle_1)
ax2.imshow(img_1)
ax2.set_title('Re-encoded')
img_c = masks_as_color(rle_0)
ax3.imshow(img_c)
ax3.set_title('Masks in colors')
img_c = masks_as_color(rle_1)
ax4.imshow(img_c)
ax4.set_title('Re-encoded in colors')
print('Check Decoding->Encoding',
      'RLE_0:', len(rle_0), '->',
      'RLE_1:', len(rle_1))
print(np.sum(img_0 - img_1), 'error')
# Out:
# Check Decoding->Encoding RLE_0: 9 -> RLE_1: 4
# 0 error

# %% [markdown]
# # Split into training and validation groups
# We stratify by the number of boats appearing so we have nice balances in each set

# %%
masks['ships'] = masks['EncodedPixels'].map(lambda c_row: 1 if isinstance(c_row, str) else 0)
unique_img_ids = masks.groupby('ImageId').agg({'ships': 'sum'}).reset_index()
unique_img_ids['has_ship'] = unique_img_ids['ships'].map(lambda x: 1.0 if x>0 else 0.0)
unique_img_ids['has_ship_vec'] = unique_img_ids['has_ship'].map(lambda x: [x])
# some files are too small/corrupt
unique_img_ids['file_size_kb'] = unique_img_ids['ImageId'].map(lambda c_img_id: 
                                                               os.stat(os.path.join(train_image_dir, 
                                                                                    c_img_id)).st_size/1024)
unique_img_ids = unique_img_ids[unique_img_ids['file_size_kb'] > 50] # keep only +50kb files
unique_img_ids['file_size_kb'].hist()
masks.drop(['ships'], axis=1, inplace=True)
unique_img_ids.sample(7)
# Out:
#              ImageId  ships  has_ship has_ship_vec  file_size_kb
# 81277  c7f4cbb77.jpg      1       1.0        [1.0]    120.344727
# 89254  dbda0f962.jpg      0       0.0        [0.0]     98.181641
# 17634  2af2fd4e0.jpg      0       0.0        [0.0]    109.783203
# 76886  bd1a8081a.jpg      0       0.0        [0.0]    129.282227
# 12841  1f4e54842.jpg      0       0.0        [0.0]    142.604492
# 6134   0ed7d1901.jpg      0       0.0        [0.0]    119.135742
# 67800  a6be9dd21.jpg      0       0.0        [0.0]    101.375977

# %% [markdown]
# ### Examine Number of Ship Images
# Here we examine how often ships appear and replace the ones without any ships with 0

# %%
unique_img_ids['ships'].hist(bins=unique_img_ids['ships'].max())

# %% [markdown]
# # Undersample Empty Images
# Here we undersample the empty images to get a better balanced group with more ships to try and segment

# %%
SAMPLES_PER_GROUP = 2000
balanced_train_df = unique_img_ids.groupby('ships').apply(lambda x: x.sample(SAMPLES_PER_GROUP) if len(x) > SAMPLES_PER_GROUP else x)
balanced_train_df['ships'].hist(bins=balanced_train_df['ships'].max()+1)
print(balanced_train_df.shape[0], 'masks')
# Out:
# 11256 masks

# %%
from sklearn.model_selection import train_test_split
train_ids, valid_ids = train_test_split(balanced_train_df, 
                 test_size = 0.2, 
                 stratify = balanced_train_df['ships'])
train_df = pd.merge(masks, train_ids)
valid_df = pd.merge(masks, valid_ids)
print(train_df.shape[0], 'training masks')
print(valid_df.shape[0], 'validation masks')
# Out:
# 27828 training masks
# 6965 validation masks

# %% [markdown]
# # Decode all the RLEs into Images
# We make a generator to produce batches of images

# %%
def make_image_gen(in_df, batch_size = BATCH_SIZE):
    all_batches = list(in_df.groupby('ImageId'))
    out_rgb = []
    out_mask = []
    while True:
        np.random.shuffle(all_batches)
        for c_img_id, c_masks in all_batches:
            rgb_path = os.path.join(train_image_dir, c_img_id)
            c_img = imread(rgb_path)
            c_mask = np.expand_dims(masks_as_image(c_masks['EncodedPixels'].values), -1)
            if IMG_SCALING is not None:
                c_img = c_img[::IMG_SCALING[0], ::IMG_SCALING[1]]
                c_mask = c_mask[::IMG_SCALING[0], ::IMG_SCALING[1]]
            out_rgb += [c_img]
            out_mask += [c_mask]
            if len(out_rgb)>=batch_size:
                yield np.stack(out_rgb, 0)/255.0, np.stack(out_mask, 0)
                out_rgb, out_mask=[], []

# %%
train_gen = make_image_gen(train_df)
train_x, train_y = next(train_gen)
print('x', train_x.shape, train_x.min(), train_x.max())
print('y', train_y.shape, train_y.min(), train_y.max())
# Out:
# x (40, 256, 256, 3) 0.0 1.0
# y (40, 256, 256, 1) 0 1

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize = (30, 10))
batch_rgb = montage_rgb(train_x)
batch_seg = montage(train_y[:, :, :, 0])
ax1.imshow(batch_rgb)
ax1.set_title('Images')
ax2.imshow(batch_seg)
ax2.set_title('Segmentations')
ax3.imshow(mark_boundaries(batch_rgb, 
                           batch_seg.astype(int)))
ax3.set_title('Outlined Ships')
fig.savefig('overview.png')
# Out:
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,

# %% [markdown]
# # Make the Validation Set

# %%
# %%time
valid_x, valid_y = next(make_image_gen(valid_df, VALID_IMG_COUNT))
print(valid_x.shape, valid_y.shape)
# Out:
# (900, 256, 256, 3) (900, 256, 256, 1)
# Wall time: 24.9 s

# %% [markdown]
# # Augment Data

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.backend.tensorflow_backend import set_session
import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.per_process_gpu_memory_fraction = 0.3
set_session(tf.Session(config=config))

dg_args = dict(featurewise_center = False, 
               samplewise_center = False, 
               rotation_range = 45, 
               width_shift_range = 0.1, 
               height_shift_range = 0.1, 
               shear_range = 0.01, 
               zoom_range = [0.9, 1.25], 
               horizontal_flip = True, 
               vertical_flip = True, 
               fill_mode = 'reflect',
               data_format = 'channels_last')

# brightness can be problematic since it seems to change the labels differently from the images 
if AUGMENT_BRIGHTNESS:
    dg_args[' brightness_range'] = [0.5, 1.5]
image_gen = ImageDataGenerator(**dg_args)

if AUGMENT_BRIGHTNESS:
    dg_args.pop('brightness_range')
label_gen = ImageDataGenerator(**dg_args)

def create_aug_gen(in_gen, seed = None):
    np.random.seed(seed if seed is not None else np.random.choice(range(9999)))
    for in_x, in_y in in_gen:
        seed = np.random.choice(range(9999))
        # keep the seeds syncronized otherwise the augmentation to the images is different from the masks
        g_x = image_gen.flow(255*in_x, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)
        g_y = label_gen.flow(in_y, 
                             batch_size = in_x.shape[0], 
                             seed = seed, 
                             shuffle=True)

        yield next(g_x)/255.0, next(g_y)
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6d8f4be0dbd0> in <module>()
#      17                data_format = 'channels_last')
#      18 # brightness can be problematic since it seems to change the labels differently from the images
# ---> 19 if AUGMENT_BRIGHTNESS:
#      20     dg_args[' brightness_range'] = [0.5, 1.5]
#      21 image_gen = ImageDataGenerator(**dg_args)
#
# NameError: name 'AUGMENT_BRIGHTNESS' is not defined

# %%
cur_gen = create_aug_gen(train_gen)
t_x, t_y = next(cur_gen)
print('x', t_x.shape, t_x.dtype, t_x.min(), t_x.max())
print('y', t_y.shape, t_y.dtype, t_y.min(), t_y.max())
# only keep first 9 samples to examine in detail
t_x = t_x[:9]
t_y = t_y[:9]
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (20, 10))
ax1.imshow(montage_rgb(t_x), cmap='gray')
ax1.set_title('images')
ax2.imshow(montage(t_y[:, :, :, 0]), cmap='gray_r')
ax2.set_title('ships')
# Out:
# x (40, 256, 256, 3) float32 0.0 1.0
# y (40, 256, 256, 1) float32 0.0 1.0
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# c:\users\cueva\miniconda3\lib\site-packages\skimage\util\_montage.py:142: skimage_deprecation: Function ``montage2d`` is deprecated and will be removed in version 0.15. Use ``montage`` instead.
#   def montage2d(arr_in, fill='mean', rescale_intensity=False, grid_shape=None,
# Text(0.5,1,'ships')

# %%
gc.collect()
# Out:
# 12

# %% [markdown]
# # Build a Model
# Here we use a slight deviation on the U-Net standard

# %%
from keras import models, layers
# Build U-Net model
def upsample_conv(filters, kernel_size, strides, padding):
    return layers.Conv2DTranspose(filters, kernel_size, strides=strides, padding=padding)
def upsample_simple(filters, kernel_size, strides, padding):
    return layers.UpSampling2D(strides)

if UPSAMPLE_MODE=='DECONV':
    upsample=upsample_conv
else:
    upsample=upsample_simple
    
input_img = layers.Input(t_x.shape[1:], name = 'RGB_Input')
pp_in_layer = input_img

if NET_SCALING is not None:
    pp_in_layer = layers.AvgPool2D(NET_SCALING)(pp_in_layer)
    
pp_in_layer = layers.GaussianNoise(GAUSSIAN_NOISE)(pp_in_layer)
pp_in_layer = layers.BatchNormalization()(pp_in_layer)

c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (pp_in_layer)
c1 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c1)
p1 = layers.MaxPooling2D((2, 2)) (c1)

c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (p1)
c2 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c2)
p2 = layers.MaxPooling2D((2, 2)) (c2)

c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (p2)
c3 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c3)
p3 = layers.MaxPooling2D((2, 2)) (c3)

c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (p3)
c4 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c4)
p4 = layers.MaxPooling2D(pool_size=(2, 2)) (c4)


c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (p4)
c5 = layers.Conv2D(128, (3, 3), activation='relu', padding='same') (c5)

u6 = upsample(64, (2, 2), strides=(2, 2), padding='same') (c5)
u6 = layers.concatenate([u6, c4])
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (u6)
c6 = layers.Conv2D(64, (3, 3), activation='relu', padding='same') (c6)

u7 = upsample(32, (2, 2), strides=(2, 2), padding='same') (c6)
u7 = layers.concatenate([u7, c3])
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (u7)
c7 = layers.Conv2D(32, (3, 3), activation='relu', padding='same') (c7)

u8 = upsample(16, (2, 2), strides=(2, 2), padding='same') (c7)
u8 = layers.concatenate([u8, c2])
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (u8)
c8 = layers.Conv2D(16, (3, 3), activation='relu', padding='same') (c8)

u9 = upsample(8, (2, 2), strides=(2, 2), padding='same') (c8)
u9 = layers.concatenate([u9, c1], axis=3)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (u9)
c9 = layers.Conv2D(8, (3, 3), activation='relu', padding='same') (c9)

d = layers.Conv2D(1, (1, 1), activation='sigmoid') (c9)
# d = layers.Cropping2D((EDGE_CROP, EDGE_CROP))(d)
# d = layers.ZeroPadding2D((EDGE_CROP, EDGE_CROP))(d)
if NET_SCALING is not None:
    d = layers.UpSampling2D(NET_SCALING)(d)

seg_model = models.Model(inputs=[input_img], outputs=[d])
seg_model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# RGB_Input (InputLayer)          (None, 256, 256, 3)  0
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 256, 256, 3)  0           RGB_Input[0][0]
# __________________________________________________________________________________________________
# gaussian_noise_1 (GaussianNoise (None, 256, 256, 3)  0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 256, 256, 3)  12          gaussian_noise_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 8)  224         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 256, 256, 8)  584         conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 8)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 16) 1168        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 16) 2320        conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 16)   0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 32)   4640        max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 32)   9248        conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 32)   0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 64)   18496       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 64)   36928       conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 64)   0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 128)  73856       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 16, 16, 128)  147584      conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 128)  0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 192)  0           up_sampling2d_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 64)   110656      concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 64)   36928       conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 64)   0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 64, 64, 96)   0           up_sampling2d_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 32)   27680       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 32)   9248        conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 128, 128, 32) 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 128, 128, 48) 0           up_sampling2d_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 128, 128, 16) 6928        concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 16) 2320        conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 256, 256, 16) 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 256, 256, 24) 0           up_sampling2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 256, 256, 8)  1736        concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 256, 256, 8)  584         conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 1)  9           conv2d_18[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 1)  0           conv2d_19[0][0]
# ==================================================================================================
# Total params: 491,149
# Trainable params: 491,143
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %%
import keras.backend as K
from keras.optimizers import Adam
from keras.losses import binary_crossentropy

## intersection over union
def IoU(y_true, y_pred, eps=1e-6):
    if np.max(y_true) == 0.0:
        return IoU(1-y_true, 1-y_pred) ## empty image; calc IoU of zeros
    intersection = K.sum(y_true * y_pred, axis=[1,2,3])
    union = K.sum(y_true, axis=[1,2,3]) + K.sum(y_pred, axis=[1,2,3]) - intersection
    return -K.mean( (intersection + eps) / (union + eps), axis=0)

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('seg_model')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.33,
                                   patience=1, verbose=1, mode='min',
                                   min_delta=0.0001, cooldown=0, min_lr=1e-8)

early = EarlyStopping(monitor="val_loss", mode="min", verbose=2,
                      patience=20) # probably needs to be more patient, but kaggle time is limited

callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
def fit():
    seg_model.compile(optimizer=Adam(1e-3, decay=1e-6), loss=IoU, metrics=['binary_accuracy'])
    
    step_count = min(MAX_TRAIN_STEPS, train_df.shape[0]//BATCH_SIZE)
    aug_gen = create_aug_gen(make_image_gen(train_df))
    loss_history = [seg_model.fit_generator(aug_gen,
                                 steps_per_epoch=step_count,
                                 epochs=MAX_TRAIN_EPOCHS,
                                 validation_data=(valid_x, valid_y),
                                 callbacks=callbacks_list,
                                workers=1 # the generator is not very thread safe
                                           )]
    return loss_history

while True:
    loss_history = fit()
    if np.min([mh.history['val_loss'] for mh in loss_history]) < -0.2:
        break
# Out:
# Epoch 1/99
# 9/9 [==============================] - 244s 27s/step - loss: -0.0062 - binary_accuracy: 0.9750 - val_loss: -0.0074 - val_binary_accuracy: 0.9945
#
# Epoch 00001: val_loss improved from inf to -0.00738, saving model to seg_model_weights.best.hdf5
# Epoch 2/99
# 9/9 [==============================] - 48s 5s/step - loss: -0.0133 - binary_accuracy: 0.9931 - val_loss: -0.0301 - val_binary_accuracy: 0.9315
#
# Epoch 00002: val_loss improved from -0.00738 to -0.03014, saving model to seg_model_weights.best.hdf5
# Epoch 3/99
# 9/9 [==============================] - 94s 10s/step - loss: -0.0468 - binary_accuracy: 0.7430 - val_loss: -0.0654 - val_binary_accuracy: 0.6072
#
# Epoch 00003: val_loss improved from -0.03014 to -0.06541, saving model to seg_model_weights.best.hdf5
# Epoch 4/99
# 9/9 [==============================] - 30s 3s/step - loss: -0.0652 - binary_accuracy: 0.6304 - val_loss: -0.0685 - val_binary_accuracy: 0.6189
#
# Epoch 00004: val_loss improved from -0.06541 to -0.06850, saving model to seg_model_weights.best.hdf5
# Epoch 5/99
# 9/9 [==============================] - 28s 3s/step - loss: -0.0770 - binary_accuracy: 0.6654 - val_loss: -0.0834 - val_binary_accuracy: 0.6166
#
# Epoch 00005: val_loss improved from -0.06850 to -0.08336, saving model to seg_model_weights.best.hdf5
# Epoch 6/99
# 9/9 [==============================] - 29s 3s/step - loss: -0.0822 - binary_accuracy: 0.6685 - val_loss: -0.0901 - val_binary_accuracy: 0.6443
#
# Epoch 00006: val_loss improved from -0.08336 to -0.09010, saving model to seg_model_weights.best.hdf5
# Epoch 7/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0954 - binary_accuracy: 0.7580 - val_loss: -0.0945 - val_binary_accuracy: 0.6719
#
# Epoch 00007: val_loss improved from -0.09010 to -0.09453, saving model to seg_model_weights.best.hdf5
# Epoch 8/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0820 - binary_accuracy: 0.7125 - val_loss: -0.0920 - val_binary_accuracy: 0.6418
#
# Epoch 00008: val_loss did not improve from -0.09453
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00033000001567415896.
# Epoch 9/99
# 9/9 [==============================] - 30s 3s/step - loss: -0.1008 - binary_accuracy: 0.6860 - val_loss: -0.0941 - val_binary_accuracy: 0.6324
#
# Epoch 00009: val_loss did not improve from -0.09453
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010890000325161964.
# Epoch 10/99
# 9/9 [==============================] - 34s 4s/step - loss: -0.0906 - binary_accuracy: 0.6979 - val_loss: -0.0946 - val_binary_accuracy: 0.6396
#
# Epoch 00010: val_loss improved from -0.09453 to -0.09460, saving model to seg_model_weights.best.hdf5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 3.5936999920522795e-05.
# Epoch 11/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0987 - binary_accuracy: 0.7168 - val_loss: -0.0951 - val_binary_accuracy: 0.6398
#
# Epoch 00011: val_loss improved from -0.09460 to -0.09509, saving model to seg_model_weights.best.hdf5
# Epoch 12/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0876 - binary_accuracy: 0.6905 - val_loss: -0.0958 - val_binary_accuracy: 0.6392
#
# Epoch 00012: val_loss improved from -0.09509 to -0.09583, saving model to seg_model_weights.best.hdf5
# Epoch 13/99
# 9/9 [==============================] - 34s 4s/step - loss: -0.0855 - binary_accuracy: 0.6986 - val_loss: -0.0963 - val_binary_accuracy: 0.6373
#
# Epoch 00013: val_loss improved from -0.09583 to -0.09632, saving model to seg_model_weights.best.hdf5
# Epoch 14/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0720 - binary_accuracy: 0.6957 - val_loss: -0.0972 - val_binary_accuracy: 0.6392
#
# Epoch 00014: val_loss improved from -0.09632 to -0.09720, saving model to seg_model_weights.best.hdf5
# Epoch 15/99
# 9/9 [==============================] - 31s 3s/step - loss: -0.0909 - binary_accuracy: 0.6931 - val_loss: -0.0978 - val_binary_accuracy: 0.6395
#
# Epoch 00015: val_loss improved from -0.09720 to -0.09782, saving model to seg_model_weights.best.hdf5
# Epoch 16/99
# 9/9 [==============================] - 35s 4s/step - loss: -0.1008 - binary_accuracy: 0.7190 - val_loss: -0.0985 - val_binary_accuracy: 0.6408
#
# Epoch 00016: val_loss improved from -0.09782 to -0.09846, saving model to seg_model_weights.best.hdf5
# Epoch 17/99
# 9/9 [==============================] - 29s 3s/step - loss: -0.0912 - binary_accuracy: 0.6964 - val_loss: -0.0985 - val_binary_accuracy: 0.6411
#
# Epoch 00017: val_loss improved from -0.09846 to -0.09853, saving model to seg_model_weights.best.hdf5
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.185920958960196e-05.
# Epoch 18/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0960 - binary_accuracy: 0.7100 - val_loss: -0.0988 - val_binary_accuracy: 0.6425
#
# Epoch 00018: val_loss improved from -0.09853 to -0.09882, saving model to seg_model_weights.best.hdf5
# Epoch 19/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0925 - binary_accuracy: 0.6904 - val_loss: -0.0993 - val_binary_accuracy: 0.6454
#
# Epoch 00019: val_loss improved from -0.09882 to -0.09926, saving model to seg_model_weights.best.hdf5
# Epoch 20/99
# 9/9 [==============================] - 30s 3s/step - loss: -0.0790 - binary_accuracy: 0.6821 - val_loss: -0.0994 - val_binary_accuracy: 0.6471
#
# Epoch 00020: val_loss improved from -0.09926 to -0.09940, saving model to seg_model_weights.best.hdf5
# Epoch 21/99
# 9/9 [==============================] - 32s 4s/step - loss: -0.1059 - binary_accuracy: 0.7134 - val_loss: -0.0995 - val_binary_accuracy: 0.6486
#
# Epoch 00021: val_loss improved from -0.09940 to -0.09952, saving model to seg_model_weights.best.hdf5
# Epoch 22/99
# 9/9 [==============================] - 28s 3s/step - loss: -0.1024 - binary_accuracy: 0.7143 - val_loss: -0.0998 - val_binary_accuracy: 0.6505
#
# Epoch 00022: val_loss improved from -0.09952 to -0.09977, saving model to seg_model_weights.best.hdf5
# Epoch 23/99
# 9/9 [==============================] - 29s 3s/step - loss: -0.0925 - binary_accuracy: 0.6933 - val_loss: -0.1001 - val_binary_accuracy: 0.6527
#
# Epoch 00023: val_loss improved from -0.09977 to -0.10011, saving model to seg_model_weights.best.hdf5
# Epoch 24/99
# 9/9 [==============================] - 28s 3s/step - loss: -0.0949 - binary_accuracy: 0.7207 - val_loss: -0.1003 - val_binary_accuracy: 0.6548
#
# Epoch 00024: val_loss improved from -0.10011 to -0.10025, saving model to seg_model_weights.best.hdf5
# Epoch 25/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0946 - binary_accuracy: 0.7285 - val_loss: -0.1003 - val_binary_accuracy: 0.6563
#
# Epoch 00025: val_loss improved from -0.10025 to -0.10027, saving model to seg_model_weights.best.hdf5
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 3.913539212589967e-06.
# Epoch 26/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.0909 - binary_accuracy: 0.7210 - val_loss: -0.1005 - val_binary_accuracy: 0.6581
#
# Epoch 00026: val_loss improved from -0.10027 to -0.10048, saving model to seg_model_weights.best.hdf5
# Epoch 27/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0977 - binary_accuracy: 0.7168 - val_loss: -0.1006 - val_binary_accuracy: 0.6593
#
# Epoch 00027: val_loss improved from -0.10048 to -0.10060, saving model to seg_model_weights.best.hdf5
# Epoch 28/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1026 - binary_accuracy: 0.7421 - val_loss: -0.1003 - val_binary_accuracy: 0.6579
#
# Epoch 00028: val_loss did not improve from -0.10060
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 1.2914679791720119e-06.
# Epoch 29/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0962 - binary_accuracy: 0.7266 - val_loss: -0.1005 - val_binary_accuracy: 0.6593
#
# Epoch 00029: val_loss did not improve from -0.10060
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 4.2618441511876884e-07.
# Epoch 30/99
# 9/9 [==============================] - 58s 6s/step - loss: -0.0937 - binary_accuracy: 0.7171 - val_loss: -0.1006 - val_binary_accuracy: 0.6599
#
# Epoch 00030: val_loss improved from -0.10060 to -0.10061, saving model to seg_model_weights.best.hdf5
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 1.4064085661402716e-07.
# Epoch 31/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.0921 - binary_accuracy: 0.7103 - val_loss: -0.1009 - val_binary_accuracy: 0.6618
#
# Epoch 00031: val_loss improved from -0.10061 to -0.10086, saving model to seg_model_weights.best.hdf5
# Epoch 32/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.1036 - binary_accuracy: 0.7362 - val_loss: -0.1006 - val_binary_accuracy: 0.6601
#
# Epoch 00032: val_loss did not improve from -0.10086
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.641148052542121e-08.
# Epoch 33/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.0886 - binary_accuracy: 0.7374 - val_loss: -0.1004 - val_binary_accuracy: 0.6588
#
# Epoch 00033: val_loss did not improve from -0.10086
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 1.5315788104430796e-08.
# Epoch 34/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.0900 - binary_accuracy: 0.7301 - val_loss: -0.1004 - val_binary_accuracy: 0.6587
#
# Epoch 00034: val_loss did not improve from -0.10086
#
# Epoch 00034: ReduceLROnPlateau reducing learning rate to 1e-08.
# Epoch 35/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.0950 - binary_accuracy: 0.7262 - val_loss: -0.1005 - val_binary_accuracy: 0.6597
#
# Epoch 00035: val_loss did not improve from -0.10086
# Epoch 36/99
# 9/9 [==============================] - 26s 3s/step - loss: -0.0943 - binary_accuracy: 0.7127 - val_loss: -0.1006 - val_binary_accuracy: 0.6603
#
# Epoch 00036: val_loss did not improve from -0.10086
# Epoch 37/99
# 9/9 [==============================] - 26s 3s/step - loss: -0.0951 - binary_accuracy: 0.7370 - val_loss: -0.1003 - val_binary_accuracy: 0.6584
#
# Epoch 00037: val_loss did not improve from -0.10086
# Epoch 38/99
# 9/9 [==============================] - 26s 3s/step - loss: -0.0996 - binary_accuracy: 0.7096 - val_loss: -0.1004 - val_binary_accuracy: 0.6588
#
# Epoch 00038: val_loss did not improve from -0.10086
# Epoch 39/99
# 9/9 [==============================] - 26s 3s/step - loss: -0.0890 - binary_accuracy: 0.7154 - val_loss: -0.1005 - val_binary_accuracy: 0.6593
#
# Epoch 00039: val_loss did not improve from -0.10086
# Epoch 40/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1089 - binary_accuracy: 0.7333 - val_loss: -0.1004 - val_binary_accuracy: 0.6588
#
# Epoch 00040: val_loss did not improve from -0.10086
# Epoch 41/99
# 9/9 [==============================] - 28s 3s/step - loss: -0.1033 - binary_accuracy: 0.7257 - val_loss: -0.1004 - val_binary_accuracy: 0.6584
#
# Epoch 00041: val_loss did not improve from -0.10086
# Epoch 42/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1047 - binary_accuracy: 0.7117 - val_loss: -0.1004 - val_binary_accuracy: 0.6589
#
# Epoch 00042: val_loss did not improve from -0.10086
# Epoch 43/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0946 - binary_accuracy: 0.7272 - val_loss: -0.1004 - val_binary_accuracy: 0.6587
#
# Epoch 00043: val_loss did not improve from -0.10086
# Epoch 44/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0992 - binary_accuracy: 0.7079 - val_loss: -0.1005 - val_binary_accuracy: 0.6590
#
# Epoch 00044: val_loss did not improve from -0.10086
# Epoch 45/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0979 - binary_accuracy: 0.7375 - val_loss: -0.1005 - val_binary_accuracy: 0.6593
#
# Epoch 00045: val_loss did not improve from -0.10086
# Epoch 46/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0935 - binary_accuracy: 0.7238 - val_loss: -0.1007 - val_binary_accuracy: 0.6606
#
# Epoch 00046: val_loss did not improve from -0.10086
# Epoch 47/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.0972 - binary_accuracy: 0.7347 - val_loss: -0.1006 - val_binary_accuracy: 0.6601
#
# Epoch 00047: val_loss did not improve from -0.10086
# Epoch 48/99
# 9/9 [==============================] - 25s 3s/step - loss: -0.0999 - binary_accuracy: 0.7425 - val_loss: -0.1002 - val_binary_accuracy: 0.6580
#
# Epoch 00048: val_loss did not improve from -0.10086
# Epoch 49/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.0895 - binary_accuracy: 0.7200 - val_loss: -0.1003 - val_binary_accuracy: 0.6583
#
# Epoch 00049: val_loss did not improve from -0.10086
# Epoch 50/99
# 9/9 [==============================] - 27s 3s/step - loss: -0.1055 - binary_accuracy: 0.7264 - val_loss: -0.1002 - val_binary_accuracy: 0.6574
#
# Epoch 00050: val_loss did not improve from -0.10086
# Epoch 51/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1134 - binary_accuracy: 0.7270 - val_loss: -0.1002 - val_binary_accuracy: 0.6576
#
# Epoch 00051: val_loss did not improve from -0.10086
# Epoch 00051: early stopping
# Epoch 1/99
# 9/9 [==============================] - 41s 5s/step - loss: -0.0979 - binary_accuracy: 0.8699 - val_loss: -0.1024 - val_binary_accuracy: 0.9858
#
# Epoch 00001: val_loss improved from -0.10086 to -0.10238, saving model to seg_model_weights.best.hdf5
# Epoch 2/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.0929 - binary_accuracy: 0.9802 - val_loss: -0.1107 - val_binary_accuracy: 0.9865
#
# Epoch 00002: val_loss improved from -0.10238 to -0.11074, saving model to seg_model_weights.best.hdf5
# Epoch 3/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.1071 - binary_accuracy: 0.9902 - val_loss: -0.1120 - val_binary_accuracy: 0.9890
#
# Epoch 00003: val_loss improved from -0.11074 to -0.11201, saving model to seg_model_weights.best.hdf5
# Epoch 4/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1330 - binary_accuracy: 0.9824 - val_loss: -0.1614 - val_binary_accuracy: 0.9580
#
# Epoch 00004: val_loss improved from -0.11201 to -0.16145, saving model to seg_model_weights.best.hdf5
# Epoch 5/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.1619 - binary_accuracy: 0.9635 - val_loss: -0.2439 - val_binary_accuracy: 0.9664
#
# Epoch 00005: val_loss improved from -0.16145 to -0.24386, saving model to seg_model_weights.best.hdf5
# Epoch 6/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.2294 - binary_accuracy: 0.9729 - val_loss: -0.2481 - val_binary_accuracy: 0.9824
#
# Epoch 00006: val_loss improved from -0.24386 to -0.24812, saving model to seg_model_weights.best.hdf5
# Epoch 7/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.2266 - binary_accuracy: 0.9781 - val_loss: -0.2979 - val_binary_accuracy: 0.9934
#
# Epoch 00007: val_loss improved from -0.24812 to -0.29793, saving model to seg_model_weights.best.hdf5
# Epoch 8/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.2683 - binary_accuracy: 0.9891 - val_loss: -0.2932 - val_binary_accuracy: 0.9844
#
# Epoch 00008: val_loss did not improve from -0.29793
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00033000001567415896.
# Epoch 9/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.2770 - binary_accuracy: 0.9859 - val_loss: -0.3029 - val_binary_accuracy: 0.9921
#
# Epoch 00009: val_loss improved from -0.29793 to -0.30295, saving model to seg_model_weights.best.hdf5
# Epoch 10/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.2652 - binary_accuracy: 0.9895 - val_loss: -0.3024 - val_binary_accuracy: 0.9925
#
# Epoch 00010: val_loss did not improve from -0.30295
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010890000325161964.
# Epoch 11/99
# 9/9 [==============================] - 24s 3s/step - loss: -0.2599 - binary_accuracy: 0.9906 - val_loss: -0.3053 - val_binary_accuracy: 0.9926
#
# Epoch 00011: val_loss improved from -0.30295 to -0.30529, saving model to seg_model_weights.best.hdf5
# Epoch 12/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.2901 - binary_accuracy: 0.9907 - val_loss: -0.3044 - val_binary_accuracy: 0.9916
#
# Epoch 00012: val_loss did not improve from -0.30529
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 3.5936999920522795e-05.
# Epoch 13/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.2970 - binary_accuracy: 0.9898 - val_loss: -0.3046 - val_binary_accuracy: 0.9912
#
# Epoch 00013: val_loss did not improve from -0.30529
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.185920958960196e-05.
# Epoch 14/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.2564 - binary_accuracy: 0.9892 - val_loss: -0.3046 - val_binary_accuracy: 0.9911
#
# Epoch 00014: val_loss did not improve from -0.30529
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 3.913539212589967e-06.
# Epoch 15/99
# 9/9 [==============================] - 23s 3s/step - loss: -0.3225 - binary_accuracy: 0.9891 - val_loss: -0.3047 - val_binary_accuracy: 0.9910
#
# Epoch 00015: val_loss did not improve from -0.30529
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.2914679791720119e-06.
# Epoch 16/99
# 8/9 [=========================>....] - ETA: 0s - loss: -0.2977 - binary_accuracy: 0.9890

# %%
def show_loss(loss_history):
    epochs = np.concatenate([mh.epoch for mh in loss_history])
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(22, 10))
    
    _ = ax1.plot(epochs, np.concatenate([mh.history['loss'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_loss'] for mh in loss_history]), 'r-')
    ax1.legend(['Training', 'Validation'])
    ax1.set_title('Loss')
    
    _ = ax2.plot(epochs, np.concatenate([mh.history['binary_accuracy'] for mh in loss_history]), 'b-',
                 epochs, np.concatenate([mh.history['val_binary_accuracy'] for mh in loss_history]), 'r-')
    ax2.legend(['Training', 'Validation'])
    ax2.set_title('Binary Accuracy (%)')

show_loss(loss_history)

# %%
seg_model.load_weights(weight_path)
seg_model.save('seg_model.h5')

# %%
pred_y = seg_model.predict(valid_x)
print(pred_y.shape, pred_y.min(axis=0).max(), pred_y.max(axis=0).min(), pred_y.mean())

# %%
fig, ax = plt.subplots(1, 1, figsize = (6, 6))
ax.hist(pred_y.ravel(), np.linspace(0, 1, 20))
ax.set_xlim(0, 1)
ax.set_yscale('log', nonposy='clip')

# %% [markdown]
# # Prepare Full Resolution Model
# Here we account for the scaling so everything can happen in the model itself

# %%
if IMG_SCALING is not None:
    fullres_model = models.Sequential()
    fullres_model.add(layers.AvgPool2D(IMG_SCALING, input_shape = (None, None, 3)))
    fullres_model.add(seg_model)
    fullres_model.add(layers.UpSampling2D(IMG_SCALING))
else:
    fullres_model = seg_model
fullres_model.save('fullres_model.h5')

# %% [markdown]
# # Visualize predictions

# %%
def raw_prediction(img, path=test_image_dir):
    c_img = imread(os.path.join(path, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    cur_seg = fullres_model.predict(c_img)[0]
    return cur_seg, c_img[0]

def smooth(cur_seg):
    return binary_opening(cur_seg>0.99, np.expand_dims(disk(2), -1))

def predict(img, path=test_image_dir):
    cur_seg, c_img = raw_prediction(img, path=path)
    return smooth(cur_seg), c_img

## Get a sample of each group of ship count
samples = valid_df.groupby('ships').apply(lambda x: x.sample(1))
fig, m_axs = plt.subplots(samples.shape[0], 4, figsize = (15, samples.shape[0]*4))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2, ax3, ax4), c_img_name in zip(m_axs, samples.ImageId.values):
    first_seg, first_img = raw_prediction(c_img_name, train_image_dir)
    ax1.imshow(first_img)
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(first_seg[:, :, 0], cmap=get_cmap('jet'))
    ax2.set_title('Model Prediction')
    reencoded = masks_as_color(multi_rle_encode(smooth(first_seg)[:, :, 0]))
    ax3.imshow(reencoded)
    ax3.set_title('Prediction Masks')
    ground_truth = masks_as_color(masks.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels'])
    ax4.imshow(ground_truth)
    ax4.set_title('Ground Truth')
    
fig.savefig('validation.png')

# %% [markdown]
# # Submission

# %%
test_paths = np.array(os.listdir(test_image_dir))
print(len(test_paths), 'test images found')

# %%
from tqdm import tqdm_notebook

def pred_encode(img, **kwargs):
    cur_seg, _ = predict(img)
    cur_rles = multi_rle_encode(cur_seg, **kwargs)
    return [[img, rle] for rle in cur_rles if rle is not None]

out_pred_rows = []
for c_img_name in tqdm_notebook(test_paths[:30000]): ## only a subset as it takes too long to run
    out_pred_rows += pred_encode(c_img_name, min_max_threshold=1.0)

# %%
sub = pd.DataFrame(out_pred_rows)
sub.columns = ['ImageId', 'EncodedPixels']
sub = sub[sub.EncodedPixels.notnull()]
sub.head()

# %%
## let's see what we got
TOP_PREDICTIONS=5
fig, m_axs = plt.subplots(TOP_PREDICTIONS, 2, figsize = (9, TOP_PREDICTIONS*5))
[c_ax.axis('off') for c_ax in m_axs.flatten()]

for (ax1, ax2), c_img_name in zip(m_axs, sub.ImageId.unique()[:TOP_PREDICTIONS]):
    c_img = imread(os.path.join(test_image_dir, c_img_name))
    c_img = np.expand_dims(c_img, 0)/255.0
    ax1.imshow(c_img[0])
    ax1.set_title('Image: ' + c_img_name)
    ax2.imshow(masks_as_color(sub.query('ImageId=="{}"'.format(c_img_name))['EncodedPixels']))
    ax2.set_title('Prediction')

# %%
sub1 = pd.read_csv('../input/sample_submission.csv')
sub1 = pd.DataFrame(np.setdiff1d(sub1['ImageId'].unique(), sub['ImageId'].unique(), assume_unique=True), columns=['ImageId'])
sub1['EncodedPixels'] = None
print(len(sub1), len(sub))

sub = pd.concat([sub, sub1])
print(len(sub))
sub.to_csv('submission.csv', index=False)
sub.head()
